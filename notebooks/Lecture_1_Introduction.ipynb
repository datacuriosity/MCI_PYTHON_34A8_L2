# %% [markdown]
# ![](https://niviki.com/wp-content/uploads/2018/05/ai-machine-learning-deep-learning.png)`

# %% [markdown]
# - Algorithm centric: Researcher --> Benchmark data --> Different Algorithms --> AI Engineer/ ML Engineer (Alg / Math)
# - Data centric: Industry --> Data --> Transform, Cleaning, Feature Engineering (80%) --> Algorithm --> Data Scientist

# %% [markdown]
# ![image.png](attachment:85e4993a-011b-408c-8b84-3ed26b6b97d1.png)

# %% [markdown]
# Machine learning:
# - Knowledges
# - Computation

# %% [markdown]
# ![image.png](attachment:c30cac41-3654-4d7f-bff8-c3e7b01da72a.png)

# %% [markdown]
# ![](https://static.javatpoint.com/tutorial/data-science/images/data-science-components2.png)

# %% [markdown]
# ![](https://miro.medium.com/max/1200/1*DjIccrMeRWmrC_mCUOGDhw.png)

# %% [markdown]
# ![](https://7wdata.be/wp-content/uploads/2020/06/1FUZS9K4JPqzfXDcC83BQTw.png)

# %% [markdown]
# ![](https://lh5.googleusercontent.com/zhU4NQ45lxz4jIhlPDz1287b9VdGGZ75T29pusJJR1BMqfOjhtQrnR-X0ycFsV87OoZbiYt7x7n8DEq2Mt9Qiys5MDGL33kDRxTI5upqm1mTUHb3QWhnpkDEdeD06ZzvQ5bPlmhK)
